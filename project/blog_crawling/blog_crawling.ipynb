# %%
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
import csv
client_id = "0YkwTXMasrJEfC7AEdwN"
client_secret = "5CIrKH7eZe"
encText = urllib.parse.quote("데이트")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    data = response_body
    f =open('blog_output.csv', 'w', encoding = 'utf-8', newline = '')
    wr = csv.writer(f)
    count = data['display']
    while(count != 0):
        count -=1
        wr.writerow([data['items'][count]['title'],data['items'][count]['postdate']])
    f.close()
else:
    print("Error Code:" + rescode)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-52dcb1a477ba> in <module>
#      19     f =open('blog_output.csv', 'w', encoding = 'utf-8', newline = '')
#      20     wr = csv.writer(f)
# ---> 21     count = data['display']
#      22     while(count != 0):
#      23         count -=1
#
# TypeError: byte indices must be integers or slices, not str

# %%
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
import csv
client_id = "0YkwTXMasrJEfC7AEdwN"
client_secret = "5CIrKH7eZe"
encText = urllib.parse.quote("데이트")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    data = response_body
    print(data.encode('uft-8'))
else:
    print("Error Code:" + rescode)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-051bd1ad9c84> in <module>
#      17     response_body = response.read()
#      18     data = response_body
# ---> 19     print(data.encode('uft-8'))
#      20 else:
#      21     print("Error Code:" + rescode)
#
# AttributeError: 'bytes' object has no attribute 'encode'

# %%
#데이터, 
#-1순위 키워드
#음식점, 맛집, 카페, 데이트, 핫플레이스, 서울 가볼만한 곳, 놀거리, 볼거리, 전시회

#2순위 키워드 - 음식점
#맛집, 맛집 추천

#2순위 키워드 - 카페
#카페 추천

#2순위 키워드 - 데이트
#데이트 추천

#2순위 키워드 - 핫플레이스
#서울 핫플레이스, 서울 가볼만한 곳, 
#핫한 카페, 핫한, 핫, 핫플

#지역명 변환

#송리단길
#가로수길
#

# %%
data = [
 {
   "id_number": "SA4784",
   "name": "Mark",
   "birthdate": None
 },
 {
   "id_number": "V410Z8",
   "name": "Vincent",
   "birthdate": "15/02/1989"
 },
 {
   "id_number": "CZ1094",
   "name": "Paul",
   "birthdate": "27/09/1994"
 }
]

for i in data:
    print(i)
    print(i['birthdate'])
    #if i['id_number'] == 'V410Z8':
        #print(i['birthdate'])
        #print(i['name'])
        #break
# Out:
# {'id_number': 'SA4784', 'name': 'Mark', 'birthdate': None}
# None
# {'id_number': 'V410Z8', 'name': 'Vincent', 'birthdate': '15/02/1989'}
# 15/02/1989
# {'id_number': 'CZ1094', 'name': 'Paul', 'birthdate': '27/09/1994'}
# 27/09/1994

# %%
import requests
from urllib.parse import urlparse


client_id = "0YkwTXMasrJEfC7AEdwN"
client_secret = "5CIrKH7eZe"
#encText = urllib.parse.quote("강남역")
def get_api_result(keyword, display, start):
    url = "https://openapi.naver.com/v1/search/blog?query=" + keyword \
          + "&display=" + str(display) \
          + "&start=" + str(start) # json 결과    
    result = requests.get(urlparse(url).geturl(),headers = {"X-Naver-Client-Id":client_id,"X-Naver-Client-Secret":client_secret})
    return result.json()


def call_and_print(keyword, page):
    json_obj = get_api_result(keyword, 100, page)
    for item in json_obj['items']:
        title = item['title'].replace("<b>", "").replace("</b>", "")
        print(title + " "+ item['postdate'])
        #print(title + "@" +item['bloggername']+"@"+item['link'])

#json_obj = result.json()#json_obj = get_api_result(keyword, 100, 101)
#print(json_obj['items'])
#for item in json_obj['items']:#    print(item['title'].replace("<b>", "").replace("</b>", ""), item['link'])
#print("display:", json_obj['display'])#print("start:", json_obj['start'])#print("items count:", len(json_obj['items']))
#for item in json_obj['items']:#    print(item)

keyword = "데이트"
call_and_print(keyword, 1)
#call_and_print(keyword, 101)
#call_and_print(keyword, 201)
#call_and_print(keyword, 301)
#call_and_print(keyword, 401)
#call_and_print(keyword, 501)#call_and_print(keyword, 601)
# Out:
# 부산 이색데이트 슈파스파 좋아요~ 20191121
# 대구 핫플레이스 성공적인 데이트 20191104
# 홍대 데이트 맛스럽다 20191113
# 엄마랑 송도 데이트 티그램 애프터눈티 20191119
# 소고기 삼합 집에서 영등포 데이트 20191119
# 맛집 입에서 살살 정석참치 영등포2호점에서 영등포 데이트! 20191121
# 안산 데이트 밥은 여기로 결정! 20191120
# 항정살 먹으면서 영등포 데이트 20191121
# 광안리 브런치 먹으며 데이트! 20191120
# 부천 데이트 애슐리퀸즈 굿굿 20191120
# 서울 명동 맛집 보나베띠에서 스테이크 파스타 데이트하기 20191113
# 강남역 데이트 제격, 매우매오 강남역별관 크림소갈비찜 20191119
# 광화문 데이트 모도우에서 한우 디너 코스 20191120
# 서면 데이트 맛집 자꾸 생각나는 밥집! 20191122
# 동탄 데이트 / 신라스테이 동탄 20191119
# 연남동 데이트 분위기부터 맛까지 완벽한 일식 미쁘동 20191107
# 연남동 데이트, 분위기 좋은 더 부엌 20191109
# 송도 센트럴파크 맛집 :: 아메리칸트레이 샐러드 데이트 20191121
# 인천 송도 레스토랑, 데이트코스로 좋아보였던 피제리아 일피노 20191111
# 범계 데이트 분위기와 맛을 다 잡은 곳 20191122
# 남양주 데이트, 팔당 카페 한강 전망의 트윈트리 20191120
# 미사 술집 LP그루브에서 이색 데이트 하고왔네요. 20191121
# 맛있게 성공한 강남역 데이트 20191101
# 데이트폭력 신고 쉬쉬하지 말고 확실하게! 20191119
# 성수동 레스토랑, 서울숲 데이트코스는 오뜨로 부엔 디아 20191122
# 건대입구역 맛집 메호르 조용한 건대 데이트 20191119
# 팔공산 데이트코스/팔공산 카페/브런치달랏 20191121
# 종로3가모텔 익선동 데이트 후 방문하기 좋은 호텔스타 20191119
# 강남역 데이트 새로운 도전! 20191118
# ...
