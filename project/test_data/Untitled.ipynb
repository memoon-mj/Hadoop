# %%
import pandas as pd

loc = pd.read_csv("전국주요상권현황(2017).csv", encoding = 'euc-kr')
loc.head(20)
# Out:
#     상권번호        상권명  시도코드    시도명  시군구코드  시군구명  상권좌표수  \
# 0   9145    홍대입구역_2    11  서울특별시   1144   마포구     19
# 1   9146    홍대입구역_3    11  서울특별시   1144   마포구     21
# 2   9147      홍익대학교    11  서울특별시   1144   마포구     46
# 3   9148     서대문역_1    11  서울특별시   1111   종로구     12
# 4   9149     서대문역_2    11  서울특별시   1141  서대문구     29
# 5   9150      신촌역_2    11  서울특별시   1141  서대문구     38
# 6   9151        이대역    11  서울특별시   1141  서대문구     21
# 7   9152      숙대입구역    11  서울특별시   1117   용산구     12
# 8   9153       신용산역    11  서울특별시   1117   용산구     11
# 9   9154  용산,전자상가_1    11  서울특별시   1117   용산구     31
# 10  9155  용산,전자상가_2    11  서울특별시   1117   용산구     16
# 11  9156  용산,전자상가_3    11  서울특별시   1117   용산구     19
# 12  9157  용산,전자상가_4    11  서울특별시   1117   용산구     15
# 13  9169     광화문역_2    11  서울특별시   1111   종로구     58
# 14  9170    동대문시장_1    11  서울특별시   1111   종로구     15
# 15  9171     동대문역_1    11  서울특별시   1111   종로구     44
# 16  9172     동대문역_2    11  서울특별시   1111   종로구     26
# ...

# %%
loc.head()
